# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/bc/5b/b8d04f920d4be17e938a8ebad48941fbb0b97b1672897178c0d470734fd2/yfinance-0.2.48-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.48-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/04/13/d9839089b900fa7b479cce495d62110cddc4bd5630a04d8469916c0e79c5/frozendict-2.4.6-py311-none-any.whl.metadata
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.7.tar.gz (939 kB)
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      ---- --------------------------------- 122.9/939.5 kB 2.4 MB/s eta 0:00:01
#      -------------- ----------------------- 358.4/939.5 kB 3.7 MB/s eta 0:00:01
#      ----------------------- -------------- 583.7/939.5 kB 4.1 MB/s eta 0:00:01
#      ------------------------------------ - 890.9/939.5 kB 4.7 MB/s eta 0:00:01
#      -------------------------------------- 939.5/939.5 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\lucia\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Obtaining dependency information for html5lib>=1.1 from https://files.pythonhosted.org/packages/6c/dd/a834df6482147d48e225a49515aabc28974ad5a4ca3215c18a882565b028/html5lib-1.1-py2.py3-none-any.whl.metadata
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lucia\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\lucia\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\lucia\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lucia\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lucia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lucia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Downloading yfinance-0.2.48-py2.py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.1 kB ? eta -:--:--
#    ---------------------------------------- 101.1/101.1 kB 5.7 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.7-py3-none-any.whl size=138951 sha256=3ed23a434541d590990db614a7e7b2059f909f84f48819467e8e75d9cdacbcdf
#   Stored in directory: c:\users\lucia\appdata\local\pip\cache\wheels\fd\28\34\9ba1363b76703fe35ae8296af28ea74578a41b83544bb9da65
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.6 html5lib-1.1 multitasking-0.0.11 peewee-3.17.7 yfinance-0.2.48

# %%
#1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#2. Salve esses dados para que você possa utilizá-los na próxima tarefa.


import yfinance as yf
import pandas as pd

# baixar Nvidia, AMD, Intel e Qualcomm from 2019 to today
nvidia = yf.download('NVDA', start='2019-01-01')
amd = yf.download('AMD', start='2019-01-01')
intel = yf.download('INTC', start='2019-01-01')
qualcomm = yf.download('QCOM', start='2019-01-01')



# juntar os dataframes em um só com todos os ativos
data = pd.concat([nvidia, amd, intel, qualcomm], axis=1)


data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           NVDA        NVDA        NVDA        NVDA
# Date
# 2024-10-30 00:00:00+00:00  139.339996  139.339996  140.330002  136.809998
# 2024-10-31 00:00:00+00:00  132.759995  132.759995  137.610001  132.110001
# 2024-11-01 00:00:00+00:00  135.399994  135.399994  137.309998  134.570007
# 2024-11-04 00:00:00+00:00  136.050003  136.050003  138.960007  135.570007
# 2024-11-05 00:00:00+00:00  139.910004  139.910004  140.370102  137.330002
#
# Price                            Open     Volume   Adj Close       Close  \
# Ticker                           NVDA       NVDA         AMD         AMD
# Date
# 2024-10-30 00:00:00+00:00  139.539993  179418100  148.600006  148.600006
# 2024-10-31 00:00:00+00:00  137.600006  270039600  144.070007  144.070007
# 2024-11-01 00:00:00+00:00  134.699997  207127800  141.860001  141.860001
# 2024-11-04 00:00:00+00:00  137.210007  187528200  140.710007  140.710007
# 2024-11-05 00:00:00+00:00  137.449997  157294904  141.660004  141.660004
#
# Price                            High         Low  ...   High        Low  \
# Ticker                            AMD         AMD  ...   INTC       INTC
# Date                                               ...
# 2024-10-30 00:00:00+00:00  153.119995  148.100006  ...  22.93  22.260000
# 2024-10-31 00:00:00+00:00  148.679993  143.330002  ...  22.25  21.469999
# 2024-11-01 00:00:00+00:00  144.539993  141.320007  ...  23.58  21.910000
# 2024-11-04 00:00:00+00:00  143.639999  139.720001  ...  23.00  22.000000
# 2024-11-05 00:00:00+00:00  143.080002  140.800003  ...  23.58  22.400000
#
# Price                           Open     Volume   Adj Close       Close  \
# Ticker                          INTC       INTC        QCOM        QCOM
# Date
# 2024-10-30 00:00:00+00:00  22.420000   50941200  167.619995  167.619995
# 2024-10-31 00:00:00+00:00  22.150000  112485500  162.770004  162.770004
# 2024-11-01 00:00:00+00:00  23.000000  173471100  165.270004  165.270004
# 2024-11-04 00:00:00+00:00  22.959999   84616300  165.179993  165.179993
# 2024-11-05 00:00:00+00:00  22.580000   58248859  165.910004  165.910004
#
# Price                            High         Low        Open    Volume
# Ticker                           QCOM        QCOM        QCOM      QCOM
# Date
# 2024-10-30 00:00:00+00:00  171.740005  167.529999  169.919998   8819700
# 2024-10-31 00:00:00+00:00  167.779999  162.080002  167.619995  10261200
# 2024-11-01 00:00:00+00:00  166.080002  162.770004  163.080002   6498100
# 2024-11-04 00:00:00+00:00  167.500000  163.639999  165.059998   4949800
# 2024-11-05 00:00:00+00:00  167.539993  164.244995  165.000000   5353682
#
# [5 rows x 24 columns]

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
data[('Amplitude', 'NVDA')] = data[('High', 'NVDA')] - data[('Low', 'NVDA')]
data[('Amplitude', 'AMD')] = data[('High', 'AMD')] - data[('Low', 'AMD')]
data[('Amplitude', 'INTC')] = data[('High', 'INTC')] - data[('Low', 'INTC')]
data[('Amplitude', 'QCOM')] = data[('High', 'QCOM')] - data[('Low', 'QCOM')]


data.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           NVDA        NVDA        NVDA        NVDA
# Date
# 2024-10-30 00:00:00+00:00  139.339996  139.339996  140.330002  136.809998
# 2024-10-31 00:00:00+00:00  132.759995  132.759995  137.610001  132.110001
# 2024-11-01 00:00:00+00:00  135.399994  135.399994  137.309998  134.570007
# 2024-11-04 00:00:00+00:00  136.050003  136.050003  138.960007  135.570007
# 2024-11-05 00:00:00+00:00  139.910004  139.910004  140.370102  137.330002
#
# Price                            Open     Volume   Adj Close       Close  \
# Ticker                           NVDA       NVDA         AMD         AMD
# Date
# 2024-10-30 00:00:00+00:00  139.539993  179418100  148.600006  148.600006
# 2024-10-31 00:00:00+00:00  137.600006  270039600  144.070007  144.070007
# 2024-11-01 00:00:00+00:00  134.699997  207127800  141.860001  141.860001
# 2024-11-04 00:00:00+00:00  137.210007  187528200  140.710007  140.710007
# 2024-11-05 00:00:00+00:00  137.449997  157294904  141.660004  141.660004
#
# Price                            High         Low  ...   Adj Close  \
# Ticker                            AMD         AMD  ...        QCOM
# Date                                               ...
# 2024-10-30 00:00:00+00:00  153.119995  148.100006  ...  167.619995
# 2024-10-31 00:00:00+00:00  148.679993  143.330002  ...  162.770004
# 2024-11-01 00:00:00+00:00  144.539993  141.320007  ...  165.270004
# 2024-11-04 00:00:00+00:00  143.639999  139.720001  ...  165.179993
# 2024-11-05 00:00:00+00:00  143.080002  140.800003  ...  165.910004
#
# Price                           Close        High         Low        Open  \
# Ticker                           QCOM        QCOM        QCOM        QCOM
# Date
# 2024-10-30 00:00:00+00:00  167.619995  171.740005  167.529999  169.919998
# 2024-10-31 00:00:00+00:00  162.770004  167.779999  162.080002  167.619995
# 2024-11-01 00:00:00+00:00  165.270004  166.080002  162.770004  163.080002
# 2024-11-04 00:00:00+00:00  165.179993  167.500000  163.639999  165.059998
# 2024-11-05 00:00:00+00:00  165.910004  167.539993  164.244995  165.000000
#
# Price                        Volume Amplitude
# Ticker                         QCOM      NVDA       AMD      INTC      QCOM
# Date
# 2024-10-30 00:00:00+00:00   8819700  3.520004  5.019989  0.670000  4.210007
# 2024-10-31 00:00:00+00:00  10261200  5.500000  5.349991  0.780001  5.699997
# 2024-11-01 00:00:00+00:00   6498100  2.739990  3.219986  1.670000  3.309998
# 2024-11-04 00:00:00+00:00   4949800  3.389999  3.919998  1.000000  3.860001
# 2024-11-05 00:00:00+00:00   5353682  3.040100  2.279999  1.180000  3.294998
#
# [5 rows x 28 columns]

# %%
# Swap the levels of the MultiIndex columns
df = data.swaplevel(axis=1)
# Sort the columns to group tickers together
df = df.sort_index(axis=1, level=0)
df.tail()
# Out:
# Ticker                            AMD                                    \
# Price                       Adj Close Amplitude       Close        High
# Date
# 2024-10-30 00:00:00+00:00  148.600006  5.019989  148.600006  153.119995
# 2024-10-31 00:00:00+00:00  144.070007  5.349991  144.070007  148.679993
# 2024-11-01 00:00:00+00:00  141.860001  3.219986  141.860001  144.539993
# 2024-11-04 00:00:00+00:00  140.710007  3.919998  140.710007  143.639999
# 2024-11-05 00:00:00+00:00  141.660004  2.279999  141.660004  143.080002
#
# Ticker                                                            INTC  \
# Price                             Low        Open    Volume  Adj Close
# Date
# 2024-10-30 00:00:00+00:00  148.100006  153.009995  87701700  22.299999
# 2024-10-31 00:00:00+00:00  143.330002  147.800003  44386600  21.520000
# 2024-11-01 00:00:00+00:00  141.320007  144.440002  39027400  23.200001
# 2024-11-04 00:00:00+00:00  139.720001  141.699997  29117400  22.520000
# 2024-11-05 00:00:00+00:00  140.800003  141.940002  26932052  23.320000
#
# Ticker                                          ...        NVDA              \
# Price                     Amplitude      Close  ...         Low        Open
# Date                                            ...
# 2024-10-30 00:00:00+00:00  0.670000  22.299999  ...  136.809998  139.539993
# 2024-10-31 00:00:00+00:00  0.780001  21.520000  ...  132.110001  137.600006
# 2024-11-01 00:00:00+00:00  1.670000  23.200001  ...  134.570007  134.699997
# 2024-11-04 00:00:00+00:00  1.000000  22.520000  ...  135.570007  137.210007
# 2024-11-05 00:00:00+00:00  1.180000  23.320000  ...  137.330002  137.449997
#
# Ticker                                      QCOM                        \
# Price                         Volume   Adj Close Amplitude       Close
# Date
# 2024-10-30 00:00:00+00:00  179418100  167.619995  4.210007  167.619995
# 2024-10-31 00:00:00+00:00  270039600  162.770004  5.699997  162.770004
# 2024-11-01 00:00:00+00:00  207127800  165.270004  3.309998  165.270004
# 2024-11-04 00:00:00+00:00  187528200  165.179993  3.860001  165.179993
# 2024-11-05 00:00:00+00:00  157294904  165.910004  3.294998  165.910004
#
# Ticker
# Price                            High         Low        Open    Volume
# Date
# 2024-10-30 00:00:00+00:00  171.740005  167.529999  169.919998   8819700
# 2024-10-31 00:00:00+00:00  167.779999  162.080002  167.619995  10261200
# 2024-11-01 00:00:00+00:00  166.080002  162.770004  163.080002   6498100
# 2024-11-04 00:00:00+00:00  167.500000  163.639999  165.059998   4949800
# 2024-11-05 00:00:00+00:00  167.539993  164.244995  165.000000   5353682
#
# [5 rows x 28 columns]

# %%
df.to_csv('stock_data_tech.csv')
